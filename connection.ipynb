# %%
##make connection with the server

# %%
import requests
from IPython.display import Image

# %%
URL = "https://ows.rasdaman.org/rasdaman/ows"

# %%
query= r"""for c in (mean_summer_airtemp) return encode(c, "png")"""

# %%
rawImage =requests.post(URL, data={"query": query}).content

# %%
Image(data=rawImage)
